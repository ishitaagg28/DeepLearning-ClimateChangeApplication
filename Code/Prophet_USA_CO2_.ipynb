# %%
#importing files
from pandas import read_csv
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from fbprophet import Prophet

# %%
#reading dataset
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/USA_CO2.csv")

# %%
#vieweing the top 5 rows within the dataframe
dataset.head(5)
# Out:
#   iso_code        country  year    co2  consumption_co2  co2_growth_prct  \
# 0      USA  United States  1800  0.253              NaN              NaN
# 1      USA  United States  1801  0.267              NaN             5.80
# 2      USA  United States  1802  0.289              NaN             8.22
# 3      USA  United States  1803  0.297              NaN             2.53
# 4      USA  United States  1804  0.333              NaN            12.35
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.042                         NaN  ...
# 1           0.015        NaN           0.044                         NaN  ...
# 2           0.022        NaN           0.046                         NaN  ...
# 3           0.007        NaN           0.047                         NaN  ...
# 4           0.037        NaN           0.052                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0             NaN      NaN                 NaN            NaN
# 1             NaN      NaN                 NaN            NaN
# 2             NaN      NaN                 NaN            NaN
# 3             NaN      NaN                 NaN            NaN
# 4             NaN      NaN                 NaN            NaN
#
#    nitrous_oxide_per_capita  population  gdp  primary_energy_consumption  \
# 0                       NaN     6000000  NaN                         NaN
# 1                       NaN     6113782  NaN                         NaN
# 2                       NaN     6229723  NaN                         NaN
# 3                       NaN     6347862  NaN                         NaN
# 4                       NaN     6468241  NaN                         NaN
#
#    energy_per_capita  energy_per_gdp
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
#
# [5 rows x 58 columns]

# %%
#dataset.info()
#dropping all columns except year and co2
dataset.drop(dataset.columns.difference(['year','co2']), 1, inplace=True)
dataset=dataset.rename(columns={'year':'yr', 'co2':'y'})
dataset.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
#      yr      y
# 0  1800  0.253
# 1  1801  0.267
# 2  1802  0.289
# 3  1803  0.297
# 4  1804  0.333

# %%
year_max = dataset['yr'].max()
year_min = dataset['yr'].min()

length = year_max - year_min +1

#creating a list of years to store all year values
yr_val = dataset['yr']

dataset['ds'] = [str(yr)+'/1/1' for yr in yr_val]


dataset['ds'] = pd.to_datetime(dataset['ds'])
dataset.head(5)
# Out:
#      yr      y         ds
# 0  1800  0.253 1800-01-01
# 1  1801  0.267 1801-01-01
# 2  1802  0.289 1802-01-01
# 3  1803  0.297 1803-01-01
# 4  1804  0.333 1804-01-01

# %%
train = dataset.iloc[:205,:]
test = dataset.iloc[205:,:]

# %%
#Forecasting using fbprophet

pred = Prophet()
pred.fit(train)
#predict the next n number of years, substitute n in periods, frequency is yearly
future = pred.make_future_dataframe(periods=25, freq = 'Y')
forecast = pred.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 0   1800-01-01   -87.297435  -317.265347   148.624385
# 1   1801-01-01   -66.276270  -297.695092   172.985662
# 2   1802-01-01   -44.617358  -289.368030   188.931066
# 3   1803-01-01   -22.344688  -262.717143   219.903545
# 4   1804-01-01     0.516717  -242.363386   240.607873
# ..         ...          ...          ...          ...
# 225 2024-12-31  7619.342582  7381.281100  7886.671793
# 226 2025-12-31  7710.737726  7467.631971  7970.297575
# 227 2026-12-31  7802.520858  7548.663586  8064.977576
# 228 2027-12-31  7894.660146  7641.010152  8157.336080
# 229 2028-12-31  7888.207527  7634.172689  8163.878747
#
# [230 rows x 4 columns]

# %%
#plotting the forecast and the forecast components
pred.plot(forecast)
pred.plot_components(forecast)

# %%
#saving the data
forecast.to_csv("/content/drive/MyDrive/Colab Notebooks/Prophet for CO2.csv")

# %%
forecast_sub  = forecast[['ds','yhat']]
forecast_sub['ds'] = pd.to_datetime(forecast_sub['ds'])
test = test[['ds','y']]
test['ds'] = pd.to_datetime(test['ds'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
test['year'] = test['ds'].dt.to_period('Y')
forecast_sub['year'] = forecast_sub['ds'].dt.to_period('Y')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
eval = test.merge(forecast_sub, on=['year'], how='left')
eval.head(5)

eval['abs_err'] = abs(eval['yhat'] - eval['y'])
total_y = sum(eval['y'])
total_error = sum(eval['abs_err'])
err =  (total_error/total_y)
print("Accuracy:", (1-err)*100 , " %")
# Out:
# Accuracy: 75.46698091789655  %
